# %%
import pandas as pd                      
import datetime as dt                     
import seaborn as sns
import scipy.stats as st
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from pmdarima.arima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
from scipy.stats import shapiro                             # check normality
from scipy.stats import kstest                              # check stationary
from statsmodels.graphics.tsaplots import plot_acf          # plot auto correlation
from statsmodels.graphics.tsaplots import plot_pacf          
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\84909\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('C:/Users/84909/Finpros/datasets/VIC.csv', index_col ="Date/Time")

# %%
date_format = "%m/%d/%Y %H:%M"

# %%
df.index = pd.to_datetime(df.index, format = date_format)
df.drop(columns = 'Ticker', inplace = True)
df.head(5)
# Out:
#                      Open  High   Low  Close  Volume  Open Interest
# Date/Time
# 2018-10-17 09:39:00  98.5  98.5  98.5   98.5     390              0
# 2018-10-17 09:40:00  98.5  98.5  98.5   98.5     760              0
# 2018-10-17 09:41:00  98.6  98.6  98.6   98.6    2060              0
# 2018-10-17 09:42:00  98.6  98.6  98.6   98.6    5540              0
# 2018-10-17 09:43:00  98.6  98.7  98.6   98.7     760              0

# %%
df = df.resample('1D').mean().dropna()

# %%
df['log_returns'] = np.log(df.Close).diff()
df.dropna(inplace=True)

# %% [markdown]
# # Thống kê mô tả
#
# Một số tham số thống kê giúp lựa chọn cổ phiếu đầu tư:

# %%
plt.figure(figsize=(15, 5))
sns.set_style("ticks")
sns.lineplot(data = df, x = "Date/Time", y = 'Close')
plt.title("The Stock Prices of FPT",size = 'x-large')
sns.despine()
plt.show()

# %% [markdown]
# Ta có thể thấy sự tăng trưởng trong giá cổ phiếu của FPT khá đều đặn từ 2019 đến tháng 1/2020. Sau đó giảm rất sâu 2-3 tháng và phục hồi lại từ tháng 4/2020.

# %%
# df.describe()

# %% [markdown]
# Trung bình returns của FPT cao nhất so với những cổ phiếu khác, độ lệch chuẩn không cao phù hợp với biểu đồ phía trên khi giá tăng đều đặn

# %%
# df.skew()

# %% [markdown]
# Tuy nhiên đầu tư chứng khoán luôn có rủi ro, nhìn chung lợi nhuận của tất cả cổ phiếu đều âm.

# %%
# df.kurtosis()

# %% [markdown]
# Độ kurtosis > 3 cho thấy khả năng xuất hiện outlier cao, đem lại rủi ro hoặc lợi nhuận lớn.

# %%
# sns.distplot(tuple(df.log_returns), kde=False, fit = st.norm)
# sns.despine()
# plt.show()

# %% [markdown]
# Ta nhận thấy dữ liệu có phân phối hình chuông, tuy nhiên chỉ số kurtosis > 3 nên đuôi của phân phối cao hơn so với phân phối chuẩn $\to$ phân phối Student.

# %%
plt.figure(figsize=(15, 5))
sns.set_style("ticks")
sns.lineplot(data = df, x = "Date/Time", y = 'log_returns')
plt.title("Log-returns",size = 'x-large')
sns.despine()
plt.show()

# %% [markdown]
# Dựa vào log-returns có thể thấy chỉ số này có tính stationary, phương sai khá ổn định từ năm 2018-2020. Sau năm 2020 xuất hiện khá nhiều outlier

# %% [markdown]
# ### 1. Kiểm tra tính chuẩn

# %% [markdown]
# ##### Shapiro-Wilk Test

# %%
shapiro(df.log_returns)
# Out:
# ShapiroResult(statistic=0.8631075620651245, pvalue=1.887719054106208e-21)

# %% [markdown]
# ##### Kolmogorov-Smirnov Test

# %%
kstest(df.log_returns, 'norm')
# Out:
# KstestResult(statistic=0.47565588340631815, pvalue=3.351692439473821e-114, statistic_location=-0.05187991143109194, statistic_sign=-1)

# %% [markdown]
# Vậy cả 2 phương pháp kiểm định đều cho kết quả p-value < 0.05, ta có đủ cơ sở để bác bỏ giả thuyết $H_0$, dữ liệu không có phân phối chuẩn

# %% [markdown]
# #### 2. Kiểm tra tính dừng - stationary

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)

# %%
test_stationarity(df.log_returns)
# Out:
# Results of dickey fuller test
# Test Statistics               -1.616537e+01
# p-value                        4.421520e-29
# No. of lags used               1.000000e+00
# Number of observations used    5.450000e+02
# critical value (1%)           -3.442406e+00
# critical value (5%)           -2.866858e+00
# critical value (10%)          -2.569602e+00
# dtype: float64

# %% [markdown]
# - p-value < 0.05 nên giá trị log returns có tính dừng

# %% [markdown]
# ## Kiểm tra AutoCorrelation

# %% [markdown]
# Ta cần kiểm tra tính tự tương quan để lựa chọn bậc mô hình phù hợp. Có 2 cách thường dùng để kiểm tra điều này:
#
# - AR Plot: tự chọn số bậc phù hợp
#
# - AIC / BIC

# %% [markdown]
# Kiểm tra sự tự tương quan trong vòng 10 ngày

# %%
plot_acf(df['log_returns'], lags = 30)
plt.show()

# %%
plot_pacf(df['log_returns'], lags = 30)
plt.show()

# %% [markdown]
# Nên ta có thể chọn lag term = 1

# %% [markdown]
# Để tìm mô hình tốt nhất dựa trên AIC, ta sử dụng package hỗ trợ:

# %%
X = df['log_returns']
size = int(len(X) * 0.8)
train, test = X[0:size], X[size:len(X)]

# %%
model = auto_arima(train, start_p=0, start_q=0,
                   max_p=8, max_q=8, m=12,
                   start_P=0, seasonal=False,
                   d=1, D=0, trace=True,
                   error_action='ignore',  
                   suppress_warnings=True, 
                   stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-2254.717, Time=0.25 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-2311.585, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-2256.716, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-2348.385, Time=0.24 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-2389.383, Time=0.24 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=-2399.809, Time=0.34 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=-2406.031, Time=0.19 sec
#  ARIMA(6,1,0)(0,0,0)[0] intercept   : AIC=-2432.560, Time=0.68 sec
#  ARIMA(7,1,0)(0,0,0)[0] intercept   : AIC=-2430.655, Time=0.93 sec
#  ARIMA(6,1,1)(0,0,0)[0] intercept   : AIC=-2432.014, Time=0.95 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=-2442.806, Time=1.15 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-2446.807, Time=1.03 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-2449.984, Time=0.83 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-2464.741, Time=0.68 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-2460.529, Time=0.60 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-2446.006, Time=0.89 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=inf, Time=0.57 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0] intercept
# Total fit time: 11.051 seconds

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  437
# Model:               SARIMAX(2, 1, 1)   Log Likelihood                1237.371
# Date:                Sun, 05 May 2024   AIC                          -2464.741
# Time:                        14:34:16   BIC                          -2444.353
# Sample:                             0   HQIC                         -2456.695
#                                 - 437
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -1.035e-05   1.39e-05     -0.746      0.455   -3.75e-05    1.68e-05
# ar.L1          0.2521      0.029      8.629      0.000       0.195       0.309
# ar.L2         -0.0817      0.025     -3.269      0.001      -0.131      -0.033
# ma.L1         -0.9861      0.009   -111.890      0.000      -1.003      -0.969
# sigma2         0.0002   5.59e-06     37.334      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.86   Jarque-Bera (JB):              2897.40
# Prob(Q):                              0.35   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.58   Skew:                            -0.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Ta thấy các hệ số ước lượng đều có $(P > |z|) < 0.05$ điều này có nghĩa các hệ số đều có ý nghĩa về mặt thống kê. Ta chấp nhận mô hình này.

# %%
# Define the ARIMA model
def arima_forecast(history):
    # Fit the model
    model = ARIMA(history, order=(1,0,1))
    model_fit = model.fit()
    # Make the prediction
    output = model_fit.forecast(step = 1)
    yhat = output[0]
    return yhat

# %% [markdown]
# ## Training

# %%
# Walk-forward validation
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    # Generate a prediction
    yhat = arima_forecast(history)
    predictions.append(yhat)
    # Add the predicted value to the training set
    obs = test[t]
    history.append(obs)

# %%
plt.figure(figsize=(15, 5))
sns.set_style("ticks")
sns.lineplot(data = df[-150:], x = "Date/Time", y = 'log_returns')
sns.lineplot(data = df[-110:], x = "Date/Time", y = predictions)
plt.title("Log-returns",size = 'x-large')
sns.despine()
plt.show()

# %%
from sklearn import metrics

# %%
binary_true = np.where(np.array(test) > 0, 1, 0)
binary_pred = np.where(np.array(predictions) > 0, 1, 0)

# %%
confusion_matrix = metrics.confusion_matrix(binary_true, binary_pred)

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])

# %%
cm_display.plot()
plt.show()

# %%
def log_returns_to_close(log_returns, initial_close):
    close_prices = initial_close * np.exp(log_returns)
    return close_prices

# %%
initial_close = df.Close[-len(test)-1:-1]
close_pred = log_returns_to_close(predictions, initial_close)

# %%
plt.figure(figsize=(15, 5))
sns.set_style("ticks")
sns.lineplot(data = df[-150:], x = "Date/Time", y = 'Close')
sns.lineplot(data = df[-150:], x = "Date/Time", y = close_pred)
plt.title("Log-returns",size = 'x-large')
sns.despine()
plt.show()

# %% [markdown]
# ## Kiểm tra sai số của mô hình
#
# Sai số của mô hình phải là nhiễu trắng (thông tin tốt / xấu) được đưa vào mô hình một cách ngẫu nhiên.
#
# Do đó ta kiểm định sai số của chúng ta có auto correlation

# %%
sm.stats.acorr_ljungbox(model.resid(), lags=[10], return_df=True)
# Out:
#       lb_stat  lb_pvalue
# 10  16.050925   0.098184

# %% [markdown]
# p-value > 0.05 nên sai số của chúng ta hoàn toàn không có auto correlation.

# %% [markdown]
# ## Inference

# %%
df = pd.read_csv('C:/Users/84909/Finpros/datasets/PNJ.csv', index_col ="Date/Time")

# %%
date_format = "%m/%d/%Y %H:%M"

# %%
df = df.drop(columns=['Ticker'])
df.index = pd.to_datetime(df.index, format = date_format)

# %%
df = df.resample('1D').mean().dropna()
df = pd.DataFrame(df['Close'])

# %%
df= np.log(df)
df.dropna(inplace=True)

# %%
predict_day = 7

# %%
train, test = df[:-predict_day], df[-predict_day:]

# %%
train_diff = train.diff().dropna()
train_diff.plot()
# Out:
# <Axes: xlabel='Date/Time'>

# %%
plot_pacf(train_diff)
plt.show()

# %%
model = auto_arima(train, start_p=0, start_q=0,
                   max_p=10, max_q=10, m=14,
                   start_P=0, seasonal=False,
                   d=1, D=0, trace=True,
                   error_action='ignore',  
                   suppress_warnings=True, 
                   stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-3470.739, Time=0.21 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-3491.289, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-3488.344, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-3472.738, Time=0.14 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-3491.858, Time=0.35 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=-3489.983, Time=0.33 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-3489.843, Time=0.37 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-3491.340, Time=0.24 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-3487.947, Time=0.41 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=-3493.856, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-3493.288, Time=0.03 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=-3491.983, Time=0.26 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-3491.841, Time=0.14 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-3493.339, Time=0.15 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=-3489.945, Time=0.17 sec
#
# Best model:  ARIMA(2,1,0)(0,0,0)[0]
# Total fit time: 3.357 seconds

# %%
pred, conf = model.predict(n_periods = 7, return_conf_int = True)

df['forecast_manual'] = [None]*len(train) + list(pred)

df[-100:].plot()
# Out:
# <Axes: xlabel='Date/Time'>

# %%
np.exp(df[-100:]).plot()
# Out:
# <Axes: xlabel='Date/Time'>

# %%
plt.figure(figsize=(15, 5))
sns.set_style("ticks")
sns.lineplot(data = np.exp(df[-100:]))
plt.fill_between(df[-7:].index, np.exp(conf[:, 0]), np.exp(conf[:, 1]), color='pink', alpha=0.3, label='95% Confidence Interval')
sns.despine()
plt.show()
