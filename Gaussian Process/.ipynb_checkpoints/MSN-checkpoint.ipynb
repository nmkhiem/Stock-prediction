# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.dates as mdates
import numpy as np
import os
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ConstantKernel, RBF, ExpSineSquared, RationalQuadratic
import warnings
warnings.filterwarnings('ignore')
companies = []
# Out:
# C:\Users\84909\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('C:/Users/84909/Finpros/datasets/FPT.csv', index_col ="Date/Time")

# %%
df = df.iloc[:, 4:5]
df = df.dropna()
df.index = pd.to_datetime(df.index)
df['Day'] = df.index.day
df['Year'], df['Month'] = df.index.year, df.index.month

# %%
df = df.resample('12H').mean().dropna()

# %%
df['log_returns'] = np.log(df.Close).diff()
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                          Close   Day    Year  Month  log_returns
# Date/Time
# 2018-12-26 00:00:00  31.084878  26.0  2018.0   12.0     0.010506
# 2018-12-26 12:00:00  30.985455  26.0  2018.0   12.0    -0.003204
# 2018-12-27 00:00:00  31.315696  27.0  2018.0   12.0     0.010602
# 2018-12-27 12:00:00  31.354364  27.0  2018.0   12.0     0.001234
# 2018-12-28 00:00:00  31.278358  28.0  2018.0   12.0    -0.002427

# %%
index = np.array([])
for year in df['Year'].unique():
    close = df.Close[df['Year'] == year]
    index = np.append(index, range(0, len(close)))

# %%
df['Index'] = index
df
# Out:
#                          Close   Day    Year  Month  log_returns  Index
# Date/Time
# 2018-12-26 00:00:00  31.084878  26.0  2018.0   12.0     0.010506    0.0
# 2018-12-26 12:00:00  30.985455  26.0  2018.0   12.0    -0.003204    1.0
# 2018-12-27 00:00:00  31.315696  27.0  2018.0   12.0     0.010602    2.0
# 2018-12-27 12:00:00  31.354364  27.0  2018.0   12.0     0.001234    3.0
# 2018-12-28 00:00:00  31.278358  28.0  2018.0   12.0    -0.002427    4.0
# ...                        ...   ...     ...    ...          ...    ...
# 2020-12-18 12:00:00  56.784091  18.0  2020.0   12.0    -0.000815  485.0
# 2020-12-21 00:00:00  57.387692  21.0  2020.0   12.0     0.010574  486.0
# 2020-12-21 12:00:00  57.388095  21.0  2020.0   12.0     0.000007  487.0
# 2020-12-22 00:00:00  57.437594  22.0  2020.0   12.0     0.000862  488.0
# 2020-12-22 12:00:00  57.825301  22.0  2020.0   12.0     0.006727  489.0
#
# [996 rows x 6 columns]

# %%
start_train = '2019-12-25'
end_train = '2020-10-31'
df_train = df[(df.index >= start_train) & (df.index <= end_train)].iloc[:, :]
df_train.head()
# Out:
#                          Close   Day    Year  Month  log_returns  Index
# Date/Time
# 2019-12-25 00:00:00  48.670168  25.0  2019.0   12.0     0.013194  490.0
# 2019-12-25 12:00:00  48.921316  25.0  2019.0   12.0     0.005147  491.0
# 2019-12-26 00:00:00  49.314016  26.0  2019.0   12.0     0.007995  492.0
# 2019-12-26 12:00:00  49.212759  26.0  2019.0   12.0    -0.002055  493.0
# 2019-12-27 00:00:00  48.794906  27.0  2019.0   12.0    -0.008527  494.0

# %%
X_train = np.array(df_train[['Year', 'Month', 'Day', 'Index']])
y_train = df_train.iloc[:, 4].values
len(X_train)
# Out:
# 426

# %%
start_predict = '2020-10-31'
end_predict = '2020-12-22'
df_predict = df[(df.index >= start_predict) & (df.index <= end_predict)]
df_predict.head()
# Out:
#                          Close  Day    Year  Month  log_returns  Index
# Date/Time
# 2020-11-02 00:00:00  51.382400  2.0  2020.0   11.0     0.010438  416.0
# 2020-11-02 12:00:00  51.466667  2.0  2020.0   11.0     0.001639  417.0
# 2020-11-03 00:00:00  52.023810  3.0  2020.0   11.0     0.010767  418.0
# 2020-11-03 12:00:00  52.230864  3.0  2020.0   11.0     0.003972  419.0
# 2020-11-04 00:00:00  52.899219  4.0  2020.0   11.0     0.012715  420.0

# %%
X_predict = np.array(df_predict[['Year', 'Month', 'Day', 'Index']])
y_test = df_predict.iloc[:, 4].values
len(X_predict)
# Out:
# 73

# %%
kernel = ConstantKernel(constant_value = 1.0) * RBF(length_scale = 1.) * ExpSineSquared() 
alpha = 1e-10
iterations = 30

gp = GaussianProcessRegressor(kernel = kernel, alpha = alpha, n_restarts_optimizer = iterations, normalize_y=False)
gp.fit(X_train, y_train)

print(gp.kernel_.get_params())
# Out:
# {'k1': 0.0126**2 * RBF(length_scale=52.8), 'k2': ExpSineSquared(length_scale=0.0123, periodicity=124), 'k1__k1': 0.0126**2, 'k1__k2': RBF(length_scale=52.8), 'k1__k1__constant_value': 0.00015955971155239714, 'k1__k1__constant_value_bounds': (1e-05, 100000.0), 'k1__k2__length_scale': 52.78451937495249, 'k1__k2__length_scale_bounds': (1e-05, 100000.0), 'k2__length_scale': 0.01232119377226284, 'k2__periodicity': 124.00649994390918, 'k2__length_scale_bounds': (1e-05, 100000.0), 'k2__periodicity_bounds': (1e-05, 100000.0)}

# %%
y_pred, y_cov = gp.predict(X_predict, return_cov = True)

gp.score(X_predict, y_test)
# Out:
# -0.04403393555988022

# %%
y_lower = y_pred - np.sqrt(np.diag(y_cov))
y_upper = y_pred + np.sqrt(np.diag(y_cov))

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_predict.index, y_test, label = 'test')
plt.plot(df_predict.index, y_pred, label = 'predict')
plt.fill_between(df_predict.index, y_lower, y_upper, alpha = 0.25, label = 'Variance')
plt.legend()
plt.show()

# %%
scaler = StandardScaler()

y_test_scaled = scaler.fit_transform(y_test.reshape(-1, 1))
y_pred_scaled = scaler.fit_transform(y_pred.reshape(-1, 1))

# %%
plt.plot(y_test_scaled)
plt.plot(y_pred_scaled)
plt.show()

# %%
def log_returns_to_close(log_returns, initial_close_price):
    cumulative_log_returns = np.cumsum(log_returns)
    close_prices = initial_close_price * np.exp(cumulative_log_returns)
    return close_prices

# %%
def confidence_interval_to_close(confidence_interval):
    lower_bound = np.exp(confidence_interval[0])
    upper_bound = np.exp(confidence_interval[1])
    return lower_bound, upper_bound

# %%
y_close_pred = log_returns_to_close(y_pred, df.Close[-y_pred.shape[0]])

# %%
y_pred_lower_close, y_pred_upper_close = confidence_interval_to_close([y_lower, y_upper])

# %%
import seaborn as sns
plt.figure(figsize=(15, 5))
sns.set_style("ticks")
sns.lineplot(data = df[:], x = "Date/Time", y = 'Close')
sns.lineplot(data = df[-y_pred.shape[0]:], x = "Date/Time", y = 'Close')
sns.lineplot(data = df[-y_pred.shape[0]:], x = "Date/Time", y = y_close_pred)
plt.fill_between(df[-y_pred.shape[0]:].index, y_close_pred - y_pred_lower_close, y_close_pred + y_pred_upper_close, color='gray', alpha=0.3, label='Confidence Interval')
plt.title("The Stock Prices of FPT",size = 'x-large')
sns.despine()
plt.show()

# %% [markdown]
# ## Volatility - Day

# %%
df = pd.read_csv('C:/Users/84909/Finpros/datasets/FPT.csv', index_col ="Date/Time")

# %%
df = df.iloc[:, 4:5]
df = df.dropna()
df.index = pd.to_datetime(df.index)
df['Day'] = df.index.day
df['Year'], df['Month'] = df.index.year, df.index.month

# %%
df = df.resample('1D').mean().dropna()

# %%
df.head()
# Out:
#                 Close   Day    Year  Month
# Date/Time
# 2018-12-25  30.760000  25.0  2018.0   12.0
# 2018-12-26  31.050159  26.0  2018.0   12.0
# 2018-12-27  31.331567  27.0  2018.0   12.0
# 2018-12-28  31.321557  28.0  2018.0   12.0
# 2019-01-02  31.232393   2.0  2019.0    1.0

# %%
index = np.array([])
for year in df['Year'].unique():
    close = df.Close[df['Year'] == year]
    index = np.append(index, range(0, len(close)))

# %%
df['Index'] = index
df['vol_5'] = df['Close'].rolling(5).std()
df.dropna(inplace = True)
df
# Out:
#                 Close   Day    Year  Month  Index     vol_5
# Date/Time
# 2019-01-02  31.232393   2.0  2019.0    1.0    0.0  0.240138
# 2019-01-03  30.578619   3.0  2019.0    1.0    1.0  0.314054
# 2019-01-04  30.522963   4.0  2019.0    1.0    2.0  0.410011
# 2019-01-07  31.240211   7.0  2019.0    1.0    3.0  0.393084
# 2019-01-08  31.211389   8.0  2019.0    1.0    4.0  0.371593
# ...               ...   ...     ...    ...    ...       ...
# 2020-12-16  57.203756  16.0  2020.0   12.0  240.0  0.249079
# 2020-12-17  56.720202  17.0  2020.0   12.0  241.0  0.305462
# 2020-12-18  56.811268  18.0  2020.0   12.0  242.0  0.287265
# 2020-12-21  57.387850  21.0  2020.0   12.0  243.0  0.291389
# 2020-12-22  57.586574  22.0  2020.0   12.0  244.0  0.370540
#
# [495 rows x 6 columns]

# %%
start_train = '2018-12-25'
end_train = '2019-12-31'
df_train = df[(df.index >= start_train) & (df.index <= end_train)].iloc[:, :]
df_train.head()
# Out:
#                 Close  Day    Year  Month  Index     vol_5
# Date/Time
# 2019-01-02  31.232393  2.0  2019.0    1.0    0.0  0.240138
# 2019-01-03  30.578619  3.0  2019.0    1.0    1.0  0.314054
# 2019-01-04  30.522963  4.0  2019.0    1.0    2.0  0.410011
# 2019-01-07  31.240211  7.0  2019.0    1.0    3.0  0.393084
# 2019-01-08  31.211389  8.0  2019.0    1.0    4.0  0.371593

# %%
X_train = np.array(df_train[['Year', 'Month', 'Day', 'Index']])
y_train = df_train.iloc[:, 5].values
len(X_train)
# Out:
# 250

# %%
start_predict = '2020-01-01'
end_predict = '2020-12-22'
df_predict = df[(df.index >= start_predict) & (df.index <= end_predict)]
df_predict.head()
# Out:
#                 Close  Day    Year  Month  Index     vol_5
# Date/Time
# 2020-01-02  49.949000  2.0  2020.0    1.0    0.0  0.447295
# 2020-01-03  49.806172  3.0  2020.0    1.0    1.0  0.439920
# 2020-01-06  48.873116  6.0  2020.0    1.0    2.0  0.430137
# 2020-01-07  49.086108  7.0  2020.0    1.0    3.0  0.489134
# 2020-01-08  48.864779  8.0  2020.0    1.0    4.0  0.522866

# %%
X_predict = np.array(df_predict[['Year', 'Month', 'Day', 'Index']])
y_test = df_predict.iloc[:, 5].values
len(X_predict)
# Out:
# 245

# %%
kernel = ConstantKernel(constant_value = 1.0) * RBF(length_scale = 1.) * ExpSineSquared() * RationalQuadratic()
alpha = 1e-10
iterations = 30

gp = GaussianProcessRegressor(kernel = kernel, alpha = alpha, n_restarts_optimizer = iterations, normalize_y=False)
gp.fit(X_train, y_train)

print(gp.kernel_.get_params())
# Out:
# {'k1': 0.365**2 * RBF(length_scale=787) * ExpSineSquared(length_scale=19.2, periodicity=1.16), 'k2': RationalQuadratic(alpha=0.127, length_scale=3.21), 'k1__k1': 0.365**2 * RBF(length_scale=787), 'k1__k2': ExpSineSquared(length_scale=19.2, periodicity=1.16), 'k1__k1__k1': 0.365**2, 'k1__k1__k2': RBF(length_scale=787), 'k1__k1__k1__constant_value': 0.13302971476384712, 'k1__k1__k1__constant_value_bounds': (1e-05, 100000.0), 'k1__k1__k2__length_scale': 787.1941523943549, 'k1__k1__k2__length_scale_bounds': (1e-05, 100000.0), 'k1__k2__length_scale': 19.241378475735623, 'k1__k2__periodicity': 1.1568027666133884, 'k1__k2__length_scale_bounds': (1e-05, 100000.0), 'k1__k2__periodicity_bounds': (1e-05, 100000.0), 'k2__length_scale': 3.212024384785513, 'k2__alpha': 0.1266611522677309, 'k2__length_scale_bounds': (1e-05, 100000.0), 'k2__alpha_bounds': (1e-05, 100000.0)}

# %%
y_pred, y_cov = gp.predict(X_predict, return_cov = True)

gp.score(X_predict, y_test)
# Out:
# -0.6656758111668604

# %%
y_lower = y_pred - np.sqrt(np.diag(y_cov))
y_upper = y_pred + np.sqrt(np.diag(y_cov))

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_predict.index, y_test, label = 'test')
plt.plot(df_predict.index, y_pred, label = 'predict')
plt.fill_between(df_predict.index, y_lower, y_upper, alpha = 0.25, label = 'Variance')
plt.legend()
plt.show()

# %%
def std_to_close(std_values, initial_close_price):
    close_prices = []
    current_close = initial_close_price
    for std in std_values:
        current_close = current_close * (1 + std)
        close_prices.append(current_close)
    return close_prices

# %%
close_from_std = std_to_close(y_pred, df.Close[-y_pred.shape[0]:].values)

# %%
y_lower = std_to_close(y_lower, df.Close[-y_pred.shape[0]:].values)
y_upper = std_to_close(y_upper, df.Close[-y_pred.shape[0]:].values)

# %%
bias = df[-y_pred.shape[0]:].Close[0] - close_from_std[0][0]

# %% [markdown]
# ## Volatility - Month

# %%
df = pd.read_csv('C:/Users/84909/Finpros/datasets/FPT.csv', index_col ="Date/Time")

# %%
df = df.iloc[:, 4:5]
df = df.dropna()
df.index = pd.to_datetime(df.index)
df['Day'] = df.index.day
df['Year'], df['Month'] = df.index.year, df.index.month

# %%
df = df.resample('1M').mean().dropna()

# %%
df.head()
# Out:
#                 Close        Day    Year  Month
# Date/Time
# 2018-12-31  31.226992  26.953728  2018.0   12.0
# 2019-01-31  31.499771  16.052310  2019.0    1.0
# 2019-02-28  33.262278  18.504448  2019.0    2.0
# 2019-03-31  33.782107  15.500661  2019.0    3.0
# 2019-04-30  35.656108  13.464663  2019.0    4.0

# %%
index = np.array([])
for year in df['Year'].unique():
    close = df.Close[df['Year'] == year]
    index = np.append(index, range(0, len(close)))

# %%
df['Index'] = index
df['vol_5'] = df['Close'].rolling(5).std()
df.dropna(inplace = True)
df
# Out:
#                 Close        Day    Year  Month  Index     vol_5
# Date/Time
# 2019-04-30  35.656108  13.464663  2019.0    4.0    3.0  1.809221
# 2019-05-31  37.361522  17.197293  2019.0    5.0    4.0  2.258182
# 2019-06-30  37.581640  15.672077  2019.0    6.0    5.0  1.986032
# 2019-07-31  39.759282  15.592577  2019.0    7.0    6.0  2.241418
# 2019-08-31  43.882153  15.959094  2019.0    8.0    7.0  3.169171
# 2019-09-30  47.845110  15.996604  2019.0    9.0    8.0  4.506013
# 2019-10-31  48.863650  15.728097  2019.0   10.0    9.0  4.918776
# 2019-11-30  49.879643  15.617258  2019.0   11.0   10.0  4.185625
# 2019-12-31  48.047336  16.087008  2019.0   12.0   11.0  2.281585
# 2020-01-31  48.648505  14.560954  2020.0    1.0    0.0  0.801325
# 2020-02-29  45.906037  15.444606  2020.0    2.0    1.0  1.476866
# 2020-03-31  41.452526  16.233270  2020.0    3.0    2.0  3.310997
# 2020-04-30  41.458807  15.553762  2020.0    4.0    3.0  3.481763
# ...

# %%
start_train = '2018-12-25'
end_train = '2019-12-31'
df_train = df[(df.index >= start_train) & (df.index <= end_train)].iloc[:, :]
df_train.head()
# Out:
#                 Close        Day    Year  Month  Index     vol_5
# Date/Time
# 2019-04-30  35.656108  13.464663  2019.0    4.0    3.0  1.809221
# 2019-05-31  37.361522  17.197293  2019.0    5.0    4.0  2.258182
# 2019-06-30  37.581640  15.672077  2019.0    6.0    5.0  1.986032
# 2019-07-31  39.759282  15.592577  2019.0    7.0    6.0  2.241418
# 2019-08-31  43.882153  15.959094  2019.0    8.0    7.0  3.169171

# %%
X_train = np.array(df_train[['Year', 'Month', 'Day', 'Index']])
y_train = df_train.iloc[:, 5].values
len(X_train)
# Out:
# 9

# %%
start_predict = '2020-01-01'
end_predict = '2020-12-22'
df_predict = df[(df.index >= start_predict) & (df.index <= end_predict)]
df_predict.head()
# Out:
#                 Close        Day    Year  Month  Index     vol_5
# Date/Time
# 2020-01-31  48.648505  14.560954  2020.0    1.0    0.0  0.801325
# 2020-02-29  45.906037  15.444606  2020.0    2.0    1.0  1.476866
# 2020-03-31  41.452526  16.233270  2020.0    3.0    2.0  3.310997
# 2020-04-30  41.458807  15.553762  2020.0    4.0    3.0  3.481763
# 2020-05-31  47.338551  16.583905  2020.0    5.0    4.0  3.343586

# %%
X_predict = np.array(df_predict[['Year', 'Month', 'Day', 'Index']])
y_test = df_predict.iloc[:, 5].values
len(X_predict)
# Out:
# 11

# %%
kernel = ConstantKernel(constant_value = 1.0) * RBF(length_scale = 1.) * ExpSineSquared() * RationalQuadratic()
alpha = 1e-10
iterations = 30

gp = GaussianProcessRegressor(kernel = kernel, alpha = alpha, n_restarts_optimizer = iterations, normalize_y=False)
gp.fit(X_train, y_train)

print(gp.kernel_.get_params())
# Out:
# {'k1': 2.35**2 * RBF(length_scale=3.56) * ExpSineSquared(length_scale=55.9, periodicity=2.82), 'k2': RationalQuadratic(alpha=2.02, length_scale=129), 'k1__k1': 2.35**2 * RBF(length_scale=3.56), 'k1__k2': ExpSineSquared(length_scale=55.9, periodicity=2.82), 'k1__k1__k1': 2.35**2, 'k1__k1__k2': RBF(length_scale=3.56), 'k1__k1__k1__constant_value': 5.530450916812885, 'k1__k1__k1__constant_value_bounds': (1e-05, 100000.0), 'k1__k1__k2__length_scale': 3.5584561739949256, 'k1__k1__k2__length_scale_bounds': (1e-05, 100000.0), 'k1__k2__length_scale': 55.85387298472552, 'k1__k2__periodicity': 2.82000313056852, 'k1__k2__length_scale_bounds': (1e-05, 100000.0), 'k1__k2__periodicity_bounds': (1e-05, 100000.0), 'k2__length_scale': 128.75810261917064, 'k2__alpha': 2.0229368707041853, 'k2__length_scale_bounds': (1e-05, 100000.0), 'k2__alpha_bounds': (1e-05, 100000.0)}

# %%
y_pred, y_cov = gp.predict(X_predict, return_cov = True)

gp.score(X_predict, y_test)
# Out:
# -1.7177130085794907

# %%
y_lower = y_pred - np.sqrt(np.diag(y_cov))
y_upper = y_pred + np.sqrt(np.diag(y_cov))

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_predict.index, y_test, label = 'test')
plt.plot(df_predict.index, y_pred, label = 'predict')
plt.fill_between(df_predict.index, y_lower, y_upper, alpha = 0.25, label = 'Variance')
plt.legend()
plt.show()

# %%
def std_to_close(std_values, initial_close_price):
    close_prices = []
    current_close = initial_close_price
    for std in std_values:
        current_close = current_close * (1 + std)
        close_prices.append(current_close)
    return close_prices

# %%
close_from_std = std_to_close(y_pred, df.Close[-y_pred.shape[0]:].values)

# %%
y_lower = std_to_close(y_lower, df.Close[-y_pred.shape[0]:].values)
y_upper = std_to_close(y_upper, df.Close[-y_pred.shape[0]:].values)
