# %%
# pip install gpflow tensorflow~=2.10.0 tensorflow-probability~=0.18.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.dates as mdates
import numpy as np
import os
import gpflow
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('FPT.csv', index_col ="Date/Time")
df.head()
# Out:
#                 Ticker   Open   High    Low  Close  Volume  Open Interest
# Date/Time
# 12/25/2018 9:15    FPT  30.89  30.89  30.89  30.89   35410              0
# 12/25/2018 9:16    FPT  30.81  30.81  30.81  30.81     190              0
# 12/25/2018 9:17    FPT  30.74  30.81  30.74  30.74    1120              0
# 12/25/2018 9:18    FPT  30.74  30.74  30.74  30.74    2120              0
# 12/25/2018 9:19    FPT  30.74  30.74  30.74  30.74   22500              0

# %%
df = df.iloc[:, 4:5]
df = df.dropna()
df.index = pd.to_datetime(df.index)
df['Day'] = df.index.day
df['Year'], df['Month'] = df.index.year, df.index.month
df = df.resample('12H').mean().dropna()
df.head()
# Out:
#                          Close   Day    Year  Month
# Date/Time
# 2018-12-25 00:00:00  30.760000  25.0  2018.0   12.0
# 2018-12-26 00:00:00  31.084878  26.0  2018.0   12.0
# 2018-12-26 12:00:00  30.985455  26.0  2018.0   12.0
# 2018-12-27 00:00:00  31.315696  27.0  2018.0   12.0
# 2018-12-27 12:00:00  31.354364  27.0  2018.0   12.0

# %% [markdown]
# ## Log-returns

# %%
df['log_returns'] = np.log(df.Close).diff()
df.dropna(inplace=True)

# %%
index = np.array([])
for year in df['Year'].unique():
    close = df.Close[df['Year'] == year]
    index = np.append(index, range(0, len(close)))
df['Index'] = index

# %%
start_train = '2018-12-25'
end_train = '2020-01-31'
df_train = df[(df.index >= start_train) & (df.index <= end_train)].iloc[:, :]
df_train.head()
# Out:
#                          Close   Day    Year  Month  log_returns  Index
# Date/Time
# 2018-12-26 00:00:00  31.084878  26.0  2018.0   12.0     0.010506    0.0
# 2018-12-26 12:00:00  30.985455  26.0  2018.0   12.0    -0.003204    1.0
# 2018-12-27 00:00:00  31.315696  27.0  2018.0   12.0     0.010602    2.0
# 2018-12-27 12:00:00  31.354364  27.0  2018.0   12.0     0.001234    3.0
# 2018-12-28 00:00:00  31.278358  28.0  2018.0   12.0    -0.002427    4.0

# %%
X_train = np.array(df_train[['Year', 'Month', 'Day', 'Index']])
y_train = df_train.iloc[:, 4].values
len(X_train)
# Out:
# 539

# %%
start_predict = '2020-01-31'
end_predict = '2020-11-22'
df_predict = df[(df.index >= start_predict) & (df.index <= end_predict)]
df_predict.head()
# Out:
#                          Close   Day    Year  Month  log_returns  Index
# Date/Time
# 2020-01-31 00:00:00  46.305077  31.0  2020.0    1.0    -0.009361   32.0
# 2020-01-31 12:00:00  44.863077  31.0  2020.0    1.0    -0.031636   33.0
# 2020-02-03 00:00:00  42.763209   3.0  2020.0    2.0    -0.047937   34.0
# 2020-02-03 12:00:00  43.988462   3.0  2020.0    2.0     0.028249   35.0
# 2020-02-04 00:00:00  44.062615   4.0  2020.0    2.0     0.001684   36.0

# %%
X_predict = np.array(df_predict[['Year', 'Month', 'Day', 'Index']])
y_test = df_predict.iloc[:, 4].values
len(X_predict)
# Out:
# 414

# %%
y_train.reshape(-1, 1).shape
# Out:
# (539, 1)

# %%
print(gpflow.kernels.ChangePoints)
# Out:
# <class 'gpflow.kernels.changepoints.ChangePoints'>

# %%
model = gpflow.models.GPR((X_train, y_train.reshape(-1, 1)),
                          kernel = gpflow.kernels.Matern32())

opt = gpflow.optimizers.Scipy()
opt.minimize(model.training_loss, model.trainable_variables)
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: -1869.5652600687401
#         x: [ 6.223e-01 -1.065e+01 -1.029e+01]
#       nit: 20
#       jac: [ 2.473e-04  4.287e-05  4.361e-04]
#      nfev: 30
#      njev: 30
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>

# %%
y_pred, y_var = model.predict_f(X_predict, full_cov = False)

# %%
y_lower = y_pred - 1.96 * np.sqrt(y_var)
y_upper = y_pred + 1.96 * np.sqrt(y_var)

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_predict.index, y_test, label = 'test')
plt.plot(df_predict.index, y_pred, label = 'predict')
plt.fill_between(df_predict.index, np.array(y_lower).squeeze(), np.array(y_upper).squeeze(), alpha = 0.25, label = 'Variance')
plt.legend()
plt.show()

# %% [markdown]
# ## Volatility

# %%
df = pd.read_csv('FPT.csv', index_col ="Date/Time")
df.head()
# Out:
#                 Ticker   Open   High    Low  Close  Volume  Open Interest
# Date/Time
# 12/25/2018 9:15    FPT  30.89  30.89  30.89  30.89   35410              0
# 12/25/2018 9:16    FPT  30.81  30.81  30.81  30.81     190              0
# 12/25/2018 9:17    FPT  30.74  30.81  30.74  30.74    1120              0
# 12/25/2018 9:18    FPT  30.74  30.74  30.74  30.74    2120              0
# 12/25/2018 9:19    FPT  30.74  30.74  30.74  30.74   22500              0

# %%
df = df.iloc[:, 4:5]
df = df.dropna()
df.index = pd.to_datetime(df.index)
df['Day'] = df.index.day
df['Year'], df['Month'] = df.index.year, df.index.month
df = df.resample('12H').mean().dropna()
df.head()
# Out:
#                          Close   Day    Year  Month
# Date/Time
# 2018-12-25 00:00:00  30.760000  25.0  2018.0   12.0
# 2018-12-26 00:00:00  31.084878  26.0  2018.0   12.0
# 2018-12-26 12:00:00  30.985455  26.0  2018.0   12.0
# 2018-12-27 00:00:00  31.315696  27.0  2018.0   12.0
# 2018-12-27 12:00:00  31.354364  27.0  2018.0   12.0

# %%
index = np.array([])
for year in df['Year'].unique():
    close = df.Close[df['Year'] == year]
    index = np.append(index, range(0, len(close)))
df['Index'] = index
df['vol_5'] = df['Close'].rolling(5).std()
df.dropna(inplace = True)
df
# Out:
#                          Close   Day    Year  Month  Index     vol_5
# Date/Time
# 2018-12-27 12:00:00  31.354364  27.0  2018.0   12.0    4.0  0.245038
# 2018-12-28 00:00:00  31.278358  28.0  2018.0   12.0    5.0  0.160130
# 2018-12-28 12:00:00  31.374182  28.0  2018.0   12.0    6.0  0.158700
# 2019-01-02 00:00:00  31.316197   2.0  2019.0    1.0    0.0  0.037358
# 2019-01-02 12:00:00  31.103043   2.0  2019.0    1.0    1.0  0.108270
# ...                        ...   ...     ...    ...    ...       ...
# 2020-12-18 12:00:00  56.784091  18.0  2020.0   12.0  485.0  0.213124
# 2020-12-21 00:00:00  57.387692  21.0  2020.0   12.0  486.0  0.307275
# 2020-12-21 12:00:00  57.388095  21.0  2020.0   12.0  487.0  0.379110
# 2020-12-22 00:00:00  57.437594  22.0  2020.0   12.0  488.0  0.328146
# 2020-12-22 12:00:00  57.825301  22.0  2020.0   12.0  489.0  0.372710
#
# [993 rows x 6 columns]

# %%
start_train = '2018-12-25'
end_train = '2020-01-31'
df_train = df[(df.index >= start_train) & (df.index <= end_train)].iloc[:, :]
df_train.head()
# Out:
#                          Close   Day    Year  Month  Index     vol_5
# Date/Time
# 2018-12-27 12:00:00  31.354364  27.0  2018.0   12.0    4.0  0.245038
# 2018-12-28 00:00:00  31.278358  28.0  2018.0   12.0    5.0  0.160130
# 2018-12-28 12:00:00  31.374182  28.0  2018.0   12.0    6.0  0.158700
# 2019-01-02 00:00:00  31.316197   2.0  2019.0    1.0    0.0  0.037358
# 2019-01-02 12:00:00  31.103043   2.0  2019.0    1.0    1.0  0.108270

# %%
X_train = np.array(df_train[['Year', 'Month', 'Day', 'Index']])
y_train = df_train.iloc[:, 5].values
len(X_train)
# Out:
# 536

# %%
start_predict = '2020-01-31'
end_predict = '2020-11-22'
df_predict = df[(df.index >= start_predict) & (df.index <= end_predict)]
df_predict.head()
# Out:
#                          Close   Day    Year  Month  Index     vol_5
# Date/Time
# 2020-01-31 00:00:00  46.305077  31.0  2020.0    1.0   32.0  0.501011
# 2020-01-31 12:00:00  44.863077  31.0  2020.0    1.0   33.0  1.045844
# 2020-02-03 00:00:00  42.763209   3.0  2020.0    2.0   34.0  1.780012
# 2020-02-03 12:00:00  43.988462   3.0  2020.0    2.0   35.0  1.639734
# 2020-02-04 00:00:00  44.062615   4.0  2020.0    2.0   36.0  1.304413

# %%
X_predict = np.array(df_predict[['Year', 'Month', 'Day', 'Index']])
y_test = df_predict.iloc[:, 5].values
len(X_predict)
# Out:
# 414

# %%
model = gpflow.models.GPR((X_train, y_train.reshape(-1, 1)),
                          kernel = gpflow.kernels.Matern32())

opt = gpflow.optimizers.Scipy()
opt.minimize(model.training_loss, model.trainable_variables)
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: -340.0335900755331
#         x: [ 4.063e+00 -2.233e+00 -2.157e+01]
#       nit: 32
#       jac: [ 7.081e-04 -1.192e-03  8.401e-07]
#      nfev: 38
#      njev: 38
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>

# %%
y_pred, y_var = model.predict_f(X_predict, full_cov = False)

# %%
y_lower = y_pred - 1.96 * np.sqrt(y_var)
y_upper = y_pred + 1.96 * np.sqrt(y_var)

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_predict.index, y_test, label = 'test')
plt.plot(df_predict.index, y_pred, label = 'predict')
plt.fill_between(df_predict.index, np.array(y_lower).squeeze(), np.array(y_upper).squeeze(), alpha = 0.25, label = 'Variance')
plt.legend()
plt.show()
